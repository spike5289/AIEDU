# %%
# 2 commands to navigate to the directory of your project and initialize it.
ls - discover files in the current terminal directory
cd - navigate to a specific directory
cd .. - navigate back to the parent of the current directory
